# %% [markdown]
# ----| Procedure |----
# 1. Load the Dataset into Pandas
# 2. Understand the Data (Check the first few rows, data types, summary statistics, missing values, and duplicates.)
# 3. Remove Duplicate Rows
# 4. Handle Missing Values
# 5. Convert Data Types
# 6. Save the Cleaned Data

# %%
import numpy as np
import pandas as pd

# %%
df =
