# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Categories

# %%
categories = pd.read_csv('categories.csv')
categories
# Out:
#     CategoryID CategoryName
# 0            1  Confections
# 1            2   Shell fish
# 2            3      Cereals
# 3            4        Dairy
# 4            5    Beverages
# 5            6      Seafood
# 6            7         Meat
# 7            8        Grain
# 8            9      Poultry
# 9           10       Snails
# 10          11      Produce

# %% [markdown]
# ### Products

# %%
products = pd.read_csv('products.csv')
products
# Out:
#      ProductID                      ProductName    Price  CategoryID   Class  \
# 0            1              Flour - Whole Wheat  74.2988           3  Medium
# 1            2       Cookie Chocolate Chip With  91.2329           3  Medium
# 2            3               Onions - Cippolini   9.1379           9  Medium
# 3            4       Sauce - Gravy, Au Jus, Mix  54.3055           9  Medium
# 4            5           Artichokes - Jerusalem  65.4771           2     Low
# ..         ...                              ...      ...         ...     ...
# 447        448         Gatorade - Xfactor Berry  76.8988           5     Low
# 448        449            Nantuket Peach Orange  42.1414           4     Low
# 449        450    Wine - Vidal Icewine Magnotta   7.1070           3     Low
# 450        451  Soup - Campbells Tomato Ravioli  93.5384           1     Low
# 451        452          Napkin White - Starched  28.5653          11     Low
#
# ...

# %%
products[products.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [ProductID, ProductName, Price, CategoryID, Class, ModifyDate, Resistant, IsAllergic, VitalityDays]
# Index: []

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ProductID     452 non-null    int64
#  1   ProductName   452 non-null    object
#  2   Price         452 non-null    float64
#  3   CategoryID    452 non-null    int64
#  4   Class         452 non-null    object
#  5   ModifyDate    452 non-null    object
#  6   Resistant     452 non-null    object
#  7   IsAllergic    452 non-null    object
#  8   VitalityDays  452 non-null    float64
# dtypes: float64(2), int64(2), object(5)
# memory usage: 31.9+ KB

# %%
# Check for null values
products_info = products.isnull().sum()
print("Null values in each column:")
print(products_info)
# Out:
# Null values in each column:
# ProductID       0
# ProductName     0
# Price           0
# CategoryID      0
# Class           0
# ModifyDate      0
# Resistant       0
# IsAllergic      0
# VitalityDays    0
# dtype: int64

# %% [markdown]
# ### Employees

# %%
employees = pd.read_csv('employees.csv')
employees
# Out:
#     EmployeeID  FirstName MiddleInitial   LastName                BirthDate  \
# 0            1     Nicole             T     Fuller  1981-03-07 00:00:00.000
# 1            2  Christine             W     Palmer  1968-01-25 00:00:00.000
# 2            3      Pablo             Y      Cline  1963-02-09 00:00:00.000
# 3            4    Darnell             O    Nielsen  1989-02-06 00:00:00.000
# 4            5    Desiree             L     Stuart  1963-05-03 00:00:00.000
# 5            6      Holly             E    Collins  1987-01-13 00:00:00.000
# 6            7   Chadwick             P       Cook  1970-05-02 00:00:00.000
# 7            8      Julie             E       Dyer  1956-12-13 00:00:00.000
# 8            9     Daphne             X       King  1956-05-02 00:00:00.000
# 9           10       Jean             P       Vang  1963-12-30 00:00:00.000
# 10          11      Sonya             E    Dickson  1976-01-14 00:00:00.000
# ...

# %%
employees.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   EmployeeID     23 non-null     int64
#  1   FirstName      23 non-null     object
#  2   MiddleInitial  23 non-null     object
#  3   LastName       23 non-null     object
#  4   BirthDate      23 non-null     object
#  5   Gender         23 non-null     object
#  6   CityID         23 non-null     int64
#  7   HireDate       23 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 1.6+ KB

# %%
# Check for null values
employees_info = employees.isnull().sum()
print("Null values in each column:")
print(employees_info)
# Out:
# Null values in each column:
# EmployeeID       0
# FirstName        0
# MiddleInitial    0
# LastName         0
# BirthDate        0
# Gender           0
# CityID           0
# HireDate         0
# dtype: int64

# %% [markdown]
# ### Countries

# %%
countries = pd.read_csv('countries.csv') 
countries
# Out:
#      CountryID CountryName CountryCode
# 0            1     Armenia          AN
# 1            2      Canada          FO
# 2            3      Belize          MK
# 3            4      Uganda          LV
# 4            5    Thailand          VI
# ..         ...         ...         ...
# 201        202   Greenland          MW
# 202        203       Niger          SH
# 203        204    Malvinas          GE
# 204        205     Mayotte          PG
# 205        206    Mongolia          MZ
#
# [206 rows x 3 columns]

# %%
countries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountryID    206 non-null    int64
#  1   CountryName  206 non-null    object
#  2   CountryCode  205 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 5.0+ KB

# %%
# Check for null values
countries_info = countries.isnull().sum()
print("Null values in each column:")
print(countries_info)
# Out:
# Null values in each column:
# CountryID      0
# CountryName    0
# CountryCode    1
# dtype: int64

# %%
countries[countries['CountryCode'].isnull()]
# Out:
#      CountryID CountryName CountryCode
# 145        146   Australia         NaN

# %%
countries[countries['CountryCode'] == 'AL']
# Out:
# Empty DataFrame
# Columns: [CountryID, CountryName, CountryCode]
# Index: []

# %% [markdown]
# Australia Code --> AL

# %%
countries.loc[countries['CountryName'] == 'Australia', 'CountryCode'] = 'AL'

# %%
countries[countries['CountryCode'].isnull()]
# Out:
# Empty DataFrame
# Columns: [CountryID, CountryName, CountryCode]
# Index: []

# %% [markdown]
# ### Cities

# %%
cities = pd.read_csv('cities.csv')
cities
# Out:
#     CityID        CityName  Zipcode  CountryID
# 0        1          Dayton    80563         32
# 1        2         Buffalo    17420         32
# 2        3         Chicago    44751         32
# 3        4         Fremont    20641         32
# 4        5  Virginia Beach    62389         32
# ..     ...             ...      ...        ...
# 91      92         Hialeah    34375         32
# 92      93          Jersey    55355         32
# 93      94         Yonkers     7430         32
# 94      95         Garland    73265         32
# 95      96      Pittsburgh    14257         32
#
# [96 rows x 4 columns]

# %%
cities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CityID     96 non-null     int64
#  1   CityName   96 non-null     object
#  2   Zipcode    96 non-null     int64
#  3   CountryID  96 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 3.1+ KB

# %%
# Check for null values
cities_info = cities.isnull().sum()
print("Null values in each column:")
print(cities_info)
# Out:
# Null values in each column:
# CityID       0
# CityName     0
# Zipcode      0
# CountryID    0
# dtype: int64

# %%
cities[cities['CountryID'] == '146']
# Out:
# Empty DataFrame
# Columns: [CityID, CityName, Zipcode, CountryID]
# Index: []

# %% [markdown]
# ### Sales

# %%
sales = pd.read_csv('sales.csv')
sales
# Out:
#          SalesID  SalesPersonID  CustomerID  ProductID  Quantity  Discount  \
# 0              1              6       27039        381         7       0.0
# 1              2             16       25011         61         7       0.0
# 2              3             13       94024         23        24       0.0
# 3              4              8       73966        176        19       0.2
# 4              5             10       32653        310         9       0.0
# ...          ...            ...         ...        ...       ...       ...
# 6758120  6758121             10       50938        300        13       0.0
# 6758121  6758122             18       85668        452        22       0.1
# 6758122  6758123             21       68409        405        18       0.0
# 6758123  6758124             17       90315        104        23       0.0
# 6758124  6758125             16       45667        305        12       0.0
#
#          TotalPrice                SalesDate     TransactionNumber
# ...

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6758125 entries, 0 to 6758124
# Data columns (total 9 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   SalesID            int64
#  1   SalesPersonID      int64
#  2   CustomerID         int64
#  3   ProductID          int64
#  4   Quantity           int64
#  5   Discount           float64
#  6   TotalPrice         float64
#  7   SalesDate          object
#  8   TransactionNumber  object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 464.0+ MB

# %%
# Check for null values
sales_info = sales.isnull().sum()
print("Null values in each column:")
print(sales_info)
# Out:
# Null values in each column:
# SalesID                  0
# SalesPersonID            0
# CustomerID               0
# ProductID                0
# Quantity                 0
# Discount                 0
# TotalPrice               0
# SalesDate            67526
# TransactionNumber        0
# dtype: int64

# %%
sales[sales['SalesDate'].isnull()]
# Out:
#          SalesID  SalesPersonID  CustomerID  ProductID  Quantity  Discount  \
# 50            51             21       12478        215         4       0.2
# 227          228             18       70321         74        18       0.0
# 295          296             21       71322        219        19       0.0
# 347          348              9       92737        352        24       0.0
# 355          356             18       48857        278        13       0.0
# ...          ...            ...         ...        ...       ...       ...
# 6757793  6757794              7       33051        412         9       0.0
# 6757833  6757834             15       22090        276         6       0.0
# 6757969  6757970             12       34077         63         9       0.0
# 6758033  6758034              9       24940         22         7       0.0
# 6758068  6758069             17       79796        439        21       0.0
#
#          TotalPrice SalesDate     TransactionNumber
# ...

# %% [markdown]
# ### Customers

# %%
customers = pd.read_csv('customers.csv')
customers
# Out:
#        CustomerID FirstName MiddleInitial   LastName  CityID  \
# 0               1  Stefanie             Y       Frye      79
# 1               2     Sandy             T      Kirby      96
# 2               3       Lee             T      Zhang      55
# 3               4    Regina             S      Avery      40
# 4               5    Daniel             S     Mccann       2
# ...           ...       ...           ...        ...     ...
# 98754       98755    Yvette             C     Campos      27
# 98755       98756    Angelo             X  Mc Millan      82
# 98756       98757     Shari             J     Prince      81
# 98757       98758    Stuart             K    Cameron      57
# 98758       98759    Willie             E     Lawson      94
#
#                             Address
# 0                     97 Oak Avenue
# 1            52 White First Freeway
# 2           921 White Fabien Avenue
# 3                     75 Old Avenue
# 4      283 South Green Hague Avenue
# ...

# %%
# Check for null values
customers_info = customers.isnull().sum()
print("Null values in each column:")
print(customers_info)
# Out:
# Null values in each column:
# CustomerID         0
# FirstName          0
# MiddleInitial    977
# LastName           0
# CityID             0
# Address            0
# dtype: int64

# %%
customers.drop('MiddleInitial', axis=1)
# Out:
#        CustomerID FirstName   LastName  CityID                       Address
# 0               1  Stefanie       Frye      79                 97 Oak Avenue
# 1               2     Sandy      Kirby      96        52 White First Freeway
# 2               3       Lee      Zhang      55       921 White Fabien Avenue
# 3               4    Regina      Avery      40                 75 Old Avenue
# 4               5    Daniel     Mccann       2  283 South Green Hague Avenue
# ...           ...       ...        ...     ...                           ...
# 98754       98755    Yvette     Campos      27               945 Oak Parkway
# 98755       98756    Angelo  Mc Millan      82              99 Fabien Street
# 98756       98757     Shari     Prince      81              791 Milton Drive
# 98757       98758    Stuart    Cameron      57            149 Clarendon Road
# 98758       98759    Willie     Lawson      94             50 Fabien Freeway
#
# [98759 rows x 5 columns]
